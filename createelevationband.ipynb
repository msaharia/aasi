# %%
from osgeo import gdal
gdal.UseExceptions()

# %%
#user-supplied
pltwidth = 15
pltheight = 10
usashp = '/glade/p/work/manab/ff/elevationbands/na_dem_15s/na_dem_15s/w001001.adf'
basinshp = 'IslandPark_WatershedDelineation.shp'

# %%
usashp = gdal.Open(usshapefile)
basinshp = gdal.Open(usshapefile)
elevation = usashp.ReadAsArray()    #Read all bands

# %%
nrows, ncols = elevation.shape
x0, dx, dxdy, y0, dydx, dy = ds.GetGeoTransform()

x1 = x0 + dx * ncols
y1 = y0 + dy * nrows

plt.figure(figsize=(pltwidth, pltheight))
plt.imshow(elevation, cmap='gist_earth', extent=[x0, x1, y1, y0])
plt.show()

# %%
# Out:
# -----------------------------------------------------------------------
# FileNotFoundError                     Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py in _readboundarydata(self, name, as_polygons)
#    1222         try:
# -> 1223             bdatfile = open(os.path.join(basemap_datadir,name+'_'+self.resolution+'.dat'),'rb')
#    1224             bdatmetafile = open(os.path.join(basemap_datadir,name+'meta_'+self.resolution+'.dat'),'r')
#
# FileNotFoundError: [Errno 2] No such file or directory: '/glade/u/home/manab/anaconda3/share/basemap/gshhs_i.dat'
#
# During handling of the above exception, another exception occurred:
#
# OSError                               Traceback (most recent call last)
# <ipython-input-44-fd41592bd58c> in <module>()
#       1 from mpl_toolkits.basemap import Basemap
#       2 map = Basemap(llcrnrlon=-0.5,llcrnrlat=39.8,urcrnrlon=4.,urcrnrlat=43.,
# ...
