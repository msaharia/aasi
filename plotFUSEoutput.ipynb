# %%
import xarray as xr
import matplotlib.pyplot as plt
from jupyterthemes import jtplot

jtplot.style(theme='grade3')

# %%
out = xr.open_dataset('/glade/p/work/manab/ff/islandpark/output/islandpark_001_runs_def.nc')
print("All variables available in the Output file: ", list(out.variables.keys()))

def plotncvar(ncvar, xlabel, ylabel):
    plt.figure(figsize=(15, 5))
    out[ncvar].plot()
    plt.ylabel(xlabel, fontsize = 16)
    plt.xlabel(ylabel, fontsize = 16)
    plt.show()
# Out:
# All variables available in the Output file:  ['ppt', 'pet', 'obsq', 'watr_1', 'watr_2', 'evap_1', 'evap_2', 'q_instnt', 'q_routed', 'time', 'latitude', 'longitude']

# %%
plotncvar('ppt', 'Precipitation', 'TIME')
plotncvar('pet', 'PET', 'TIME')
plotncvar('q_instnt', 'Instant Q', 'TIME')
plotncvar('q_routed', 'Routed Q', 'TIME')
plotncvar('obsq', 'Obs Q', 'TIME')
plotncvar('watr_1', 'Total Storage (Upper Soil Layer)', 'TIME')
plotncvar('watr_2', 'Total Storage (Lower Soil Layer)', 'TIME')
plotncvar('evap_1', 'Evaporation (Upper Soil Layer)', 'TIME')
plotncvar('evap_2', 'Evaporation (Lower Soil Layer)', 'TIME')
